# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Renjith KP\Downloads\austo_automobile+%282%29+%281%29.csv")

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
df.head()
# Out:
#    Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   53    Male   Business        Married  Post Graduate                 4
# 1   53   Femal   Salaried        Married  Post Graduate                 4
# 2   53  Female   Salaried        Married  Post Graduate                 3
# 3   53  Female   Salaried        Married       Graduate                 2
# 4   53    Male   Salaried        Married  Post Graduate                 3
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No         No             Yes   99300         70700.0
# 1           Yes         No             Yes   95500         70300.0
# 2            No         No             Yes   97300         60700.0
# 3           Yes         No             Yes   72500         70300.0
# 4            No         No             Yes   79700         60200.0
#
#    Total_salary  Price Make
# 0        170000  61000  SUV
# 1        165800  61000  SUV
# 2        158000  57000  SUV
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# Analysts are required to explore data and reflect on the insights. Clear writing skill is an integral part of a good report. Note that the explanations must be such that readers with minimum knowledge of analytics is able to grasp the insight.
# Austo Motor Company is a leading car manufacturer specializing in SUV, Sedan, and Hatchback models. In its recent board meeting, concerns were raised by the members on the efficiency of the marketing campaign currently being used. The board decides to rope in an analytics professional to improve the existing campaign.

# %% [markdown]
# 1. You as an analyst have been tasked with performing a thorough analysis of the data and coming up with insights to improve the marketing campaign.

# %% [markdown]
# 1. A .  What is the important technical information about the dataset that a database administrator would be interested in? (Hint: Information about the size of the dataset and the nature of the variables)

# %%
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# 1.	B . Take a critical look at the data and do a preliminary analysis of the variables. Do a quality check of the data so that the variables are consistent? Are there any discrepancies present in the data?

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
from scipy.stats import skew

# %%
from scipy import stats

# %%
skew(df[['Age','Salary']])
# Out:
# array([ 0.89223953, -0.01155983])

# %%
df['Partner_working'].value_counts()
# Out:
# Yes    868
# No     713
# Name: Partner_working, dtype: int64

# %%
df['Marital_status'].value_counts()
# Out:
# Married    1443
# Single      138
# Name: Marital_status, dtype: int64

# %%
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     31.922201      8.425978     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  60392.220114  14674.825044  30000.0  51900.0
# Partner_salary    1475.0  20225.559322  19573.149277      0.0      0.0
# Total_salary      1581.0  79625.996205  25545.857768  30000.0  60500.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      54.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59500.0  71800.0   99300.0
# Partner_salary    25600.0  38300.0   80500.0
# Total_salary      78000.0  95900.0  171000.0
# Price             31000.0  47000.0   70000.0

# %%
df['Gender'].value_counts()
# Out:
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: Gender, dtype: int64

# %%
df['Gender'].replace('Femle','Female',inplace = True)
df['Gender'].replace('Femal','Female',inplace = True)

# %%
df['Gender'].value_counts()
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64

# %%
df['Profession'].value_counts()
# Out:
# Salaried    896
# Business    685
# Name: Profession, dtype: int64

# %%
df['Marital_status'].value_counts()
# Out:
# Married    1443
# Single      138
# Name: Marital_status, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Post Graduate    985
# Graduate         596
# Name: Education, dtype: int64

# %%
df['Personal_loan'].value_counts()
# Out:
# Yes    792
# No     789
# Name: Personal_loan, dtype: int64

# %%
df['House_loan'].value_counts()
# Out:
# No     1054
# Yes     527
# Name: House_loan, dtype: int64

# %%
df['Partner_working'].value_counts()
# Out:
# Yes    868
# No     713
# Name: Partner_working, dtype: int64

# %%
df['Make'].value_counts()
# Out:
# Sedan        702
# Hatchback    582
# SUV          297
# Name: Make, dtype: int64

# %%
df['No_of_Dependents'].value_counts()
# Out:
# 3    557
# 2    557
# 1    229
# 4    218
# 0     20
# Name: No_of_Dependents, dtype: int64

# %%
df['Partner_salary'].describe()
# Out:
# count     1475.000000
# mean     20225.559322
# std      19573.149277
# min          0.000000
# 25%          0.000000
# 50%      25600.000000
# 75%      38300.000000
# max      80500.000000
# Name: Partner_salary, dtype: float64

# %%
sns.histplot(data=df['Partner_salary'],kde=True)
# Out:
# <AxesSubplot:xlabel='Partner_salary', ylabel='Count'>

# %%
sns.boxplot(data=df,x='Partner_salary')
# Out:
# <AxesSubplot:xlabel='Partner_salary'>

# %% [markdown]
# 1. C. Explore all the features of the data separately by using appropriate visualizations and draw insights that can be utilized by the business.

# %%
df[['Age','Salary','Partner_salary','Total_salary','Price']].describe().T
# Out:
#                  count          mean           std      min      25%      50%  \
# Age             1581.0     31.922201      8.425978     22.0     25.0     29.0
# Salary          1581.0  60392.220114  14674.825044  30000.0  51900.0  59500.0
# Partner_salary  1475.0  20225.559322  19573.149277      0.0      0.0  25600.0
# Total_salary    1581.0  79625.996205  25545.857768  30000.0  60500.0  78000.0
# Price           1581.0  35597.722960  13633.636545  18000.0  25000.0  31000.0
#
#                     75%       max
# Age                38.0      54.0
# Salary          71800.0   99300.0
# Partner_salary  38300.0   80500.0
# Total_salary    95900.0  171000.0
# Price           47000.0   70000.0

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 0

# %%
fig, axes=plt.subplots(nrows=5,ncols=2)
fig.set_size_inches(15,20)
sns.histplot(df['Age'],kde=True,ax=axes[0][0])
sns.boxplot(x='Age',data=df,ax=axes[0][1])
sns.histplot(df['Salary'],kde=True,ax=axes[1][0])
sns.boxplot(x='Salary',data=df,ax=axes[1][1])
sns.histplot(df['Partner_salary'],kde=True,ax=axes[2][0])
sns.boxplot(x='Partner_salary',data=df,ax=axes[2][1])
sns.histplot(df['Total_salary'],kde=True,ax=axes[3][0])
sns.boxplot(x='Total_salary',data=df,ax=axes[3][1])
sns.histplot(df['Price'],kde=True,ax=axes[4][0])
sns.boxplot(x='Price',data=df,ax=axes[4][1])
plt.show()

# %%
fig, axes=plt.subplots(nrows=5,ncols=2)
fig.set_size_inches(15,20)
sns.countplot(data=df,x='Gender',ax=axes[0][0])
sns.countplot(data=df,x='Profession',ax=axes[0][1])
sns.countplot(data=df,x='Marital_status',ax=axes[1][0])
sns.countplot(data=df,x='Education',ax=axes[1][1])
sns.countplot(data=df,x='Personal_loan',ax=axes[2][0])
sns.countplot(data=df,x='House_loan',ax=axes[2][1])
sns.countplot(data=df,x='Partner_working',ax=axes[3][0])
sns.countplot(data=df,x='No_of_Dependents',ax=axes[3][1])
sns.countplot(data=df,x='Make',ax=axes[4][0])
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %% [markdown]
# 1.D. Understanding the relationships among the variables in the dataset is crucial for every analytical project. Perform analysis on the data fields to gain deeper insights. Comment on your understanding of the data.

# %%
fig, axes=plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(12,12)
sns.scatterplot(data=df,x='Salary',y='Price',ax=axes[0][0]).set(title='Salary vs Price of the Car')
sns.scatterplot(data=df,x='Age',y='Price',ax=axes[0][1]).set(title='Age vs Price of the Car')
sns.scatterplot(data=df,x='Partner_salary',y='Price',ax=axes[1][0]).set(title='Partner_salary vs Price of the Car')
sns.scatterplot(data=df,x='Total_salary',y='Price',ax=axes[1][1]).set(title='Total_salary vs Price of the Car')
# Out:
# [Text(0.5, 1.0, 'Total_salary vs Price of the Car')]

# %%
fig, axes=plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(17,25)
sns.countplot(data=df,x='Profession',hue='Make',ax=axes[0][0])
sns.countplot(data=df,x='Marital_status',hue='Make',ax=axes[0][1])
sns.countplot(data=df,x='Education',hue='Make',ax=axes[1][0])
sns.countplot(data=df,x='Personal_loan',hue='Make',ax=axes[1][1])
sns.countplot(data=df,x='House_loan',hue='Make',ax=axes[2][0])
sns.countplot(data=df,x='Partner_working',hue='Make',ax=axes[2][1])
sns.countplot(data=df,x='No_of_Dependents',hue='Make',ax=axes[3][0])
sns.countplot(data=df,x='Gender',hue='Make',ax=axes[3][1])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Make')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
fig, axes=plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(12,16)
sns.boxplot(data=df,x='Profession',y='Price',ax=axes[0][0])
sns.boxplot(data=df,x='Marital_status',y='Price',ax=axes[0][1])
sns.boxplot(data=df,x='Personal_loan',y='Price',ax=axes[1][0])
sns.boxplot(data=df,x='Gender',y='Price',ax=axes[1][1])
sns.boxplot(data=df,x='Education',y='Price',ax=axes[2][0])
sns.boxplot(data=df,x='House_loan',y='Price',ax=axes[2][1])
sns.boxplot(data=df,x='Partner_working',y='Price',ax=axes[3][0])
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='Price'>

# %%
fig, axes=plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(2,30)
sns.boxplot(data=df,x='Gender',y='Price',hue='Profession',ax=axes[0][0])
sns.boxplot(data=df,x='Gender',y='Price',hue='Marital_status',ax=axes[0][1])
sns.boxplot(data=df,x='Gender',y='Price',hue='Education',ax=axes[1][0])
sns.boxplot(data=df,x='Gender',y='Price',hue="Partner_working",ax=axes[1][1])
sns.boxplot(data=df,x='Education',y='Price',hue='Profession',ax=axes[2][0])
sns.boxplot(data=df,x='Make',y='Price',hue='Gender',ax=axes[2][1])
sns.boxplot(data=df,x='Make',y='Price',hue='Profession',ax=axes[3][0])
sns.boxplot(data=df,x='Make',y='Price',hue='Marital_status',ax=axes[3][1])
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Price'>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(),annot=True,fmt=".2f");

# %% [markdown]
# 1.E. Employees working on the existing marketing campaign have made the following remarks. Based on the data and your analysis state whether you agree or disagree with their observations. Justify your answer Based on the data available.

# %% [markdown]
# 1.E1) Steve Roger says “Men prefer SUV by a large margin, compared to the women”

# %%
sns.countplot(data=df,x='Make',hue='Gender');

# %% [markdown]
# 1.E2) Ned Stark believes that a salaried person is more likely to buy a Sedan

# %%
sns.countplot(data=df,x='Profession',hue='Make');

# %% [markdown]
# 1.E3) Sheldon Cooper does not believe any of them; he claims that a salaried male is an easier target for a SUV sale over a Sedan Sale.

# %%
sns.catplot(x="Profession", col="Gender",hue='Make', data=df, kind="count");

# %% [markdown]
# 1.F. From the given data, comment on the amount spent on purchasing automobiles across the following categories. Comment on how a Business can utilize the results from this exercise. Give justification along with presenting metrics/charts used for arriving at the conclusions.
# Give justification along with presenting metrics/charts used for arriving at the conclusions.

# %% [markdown]
# 1.F1) Gender

# %%
sns.boxplot(data=df,x='Gender',y='Price')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Price'>

# %%
pivot1 = pd.pivot_table(data=df, 
                        index=['Gender'], 
                        values='Price',
                        aggfunc=['mean','median','sum'])
pivot1
# Out:
#                 mean median       sum
#                Price  Price     Price
# Gender
# Female  47705.167173  49000  15695000
# Male    32817.347790  29000  39348000

# %% [markdown]
# 1.F2) Personal_loan

# %%
sns.boxplot(data=df,x='Personal_loan',y='Price')
# Out:
# <AxesSubplot:xlabel='Personal_loan', ylabel='Price'>

# %%
pivot2 = pd.pivot_table(data=df, 
                        index=['Personal_loan'], 
                        values='Price',
                        aggfunc=['mean','median','sum'])
pivot2
# Out:
#                        mean median       sum
#                       Price  Price     Price
# Personal_loan
# No             36742.712294  32000  28990000
# Yes            34457.070707  31000  27290000

# %% [markdown]
# 1.G. From the current data set comment if having a working partner leads to the purchase of a higher-priced car.

# %%
sns.boxplot(data=df,x='Partner_working',y='Price')
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='Price'>

# %%
pivot3 = pd.pivot_table(data=df, 
                        index=['Partner_working'], 
                        values='Price',
                        aggfunc=['mean','median'])
pivot3
# Out:
#                          mean median
#                         Price  Price
# Partner_working
# No               36000.000000  31000
# Yes              35267.281106  31000

# %% [markdown]
# 1.H. The main objective of this analysis is to devise an improved marketing strategy to send targeted information to different groups of potential buyers present in the data. For the current analysis use the Gender and Marital_status - fields to arrive at groups with similar purchase history.

# %%
sns.catplot(x="Make", col="Gender",hue='Marital_status', data=df, kind="count")

# %%
sns.catplot(x="Gender", y="Price", col="Make",hue='Marital_status', data=df, kind="box")

# %%
sns.catplot(x="Marital_status", y="Price",hue='Gender', data=df, kind="box")

# %%
sns.countplot(x="Gender",hue='Marital_status', data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Problem 2

# %% [markdown]
# A bank can generate revenue in a variety of ways, such as charging interest, transaction fees and financial advice. Interest charged on the capital that the bank lends out to customers has historically been the most significant method of revenue generation. The bank earns profits from the difference between the interest rates it pays on deposits and other sources of funds, and the interest rates it charges on the loans it gives out.
#
# GODIGT Bank is a mid-sized private bank that deals in all kinds of banking products, such as savings accounts, current accounts, investment products, etc. among other offerings. The bank also cross-sells asset products to its existing customers through personal loans, auto loans, business loans, etc., and to do so they use various communication methods including cold calling, e-mails, recommendations on the net banking, mobile banking, etc.
#
# GODIGT Bank also has a set of customers who were given credit cards based on risk policy and customer category class but due to huge competition in the credit card market, the bank is observing high attrition in credit card spending. The bank makes money only if customers spend more on credit cards. Given the attrition, the Bank wants to revisit its credit card policy and make sure that the card given to the customer is the right credit card. The bank will make a profit only through the customers that show higher intent towards a recommended credit card. (Higher intent means consumers would want to use the card and hence not be attrite.)

# %% [markdown]
# Analyze the dataset and list down the top 5 important variables, along with the business justifications. (10 Points)

# %%
df1 = pd.read_excel(r"C:\Users\Renjith KP\Downloads\godigt_cc_data.xlsx")

# %%
df1.head()
# Out:
#    userid              card_no  card_bin_no Issuer   card_type  \
# 0       1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1       2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2       3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3       4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4       5  4377 48XX XXXX XXXX       437748   Visa        edge
#
#   card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0       2019-09-29             B          0          1          1  ...
# 1       2002-10-30             A          1          1          1  ...
# 2       2013-10-05             C          0          0          0  ...
# 3       1999-06-01             E          0          1          1  ...
# 4       2006-06-13             B          1          1          1  ...
#
#    bank_vintage  T+1_month_activity  T+2_month_activity T+3_month_activity  \
# 0            27                   0                   0                  0
# ...

# %%
df1.describe().T
# Out:
#                           count          mean           std       min  \
# userid                   8448.0  4.224500e+03  2.438872e+03       1.0
# card_bin_no              8448.0  4.367470e+05  3.048975e+04  376916.0
# active_30                8448.0  2.923769e-01  4.548815e-01       0.0
# active_60                8448.0  4.947917e-01  5.000025e-01       0.0
# active_90                8448.0  6.420455e-01  4.794271e-01       0.0
# cc_active30              8448.0  2.840909e-01  4.510070e-01       0.0
# cc_active60              8448.0  4.844934e-01  4.997891e-01       0.0
# cc_active90              8448.0  6.323390e-01  4.821970e-01       0.0
# widget_products          8448.0  3.614583e+00  2.273193e+00       0.0
# engagement_products      8448.0  3.991122e+00  2.572135e+00       0.0
# annual_income_at_source  8448.0  1.674595e+06  1.064307e+06  200095.0
# bank_vintage             8448.0  3.316418e+01  1.586834e+01       6.0
# ...

# %%
df1.groupby(['Issuer'])['avg_spends_l3m'].mean()
# Out:
# Issuer
# Amex          48976.571429
# Mastercard    49915.589286
# Visa          49521.907817
# Name: avg_spends_l3m, dtype: float64

# %%
df1['Occupation_at_source'].value_counts()
# Out:
# Salaried         3918
# Self Employed    2175
# Retired          1089
# Student           621
# Housewife         384
# Name: Occupation_at_source, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userid                   8448 non-null   int64
#  1   card_no                  8448 non-null   object
#  2   card_bin_no              8448 non-null   int64
#  3   Issuer                   8448 non-null   object
#  4   card_type                8448 non-null   object
#  5   card_source_date         8448 non-null   datetime64[ns]
#  6   high_networth            8448 non-null   object
#  7   active_30                8448 non-null   int64
#  8   active_60                8448 non-null   int64
#  9   active_90                8448 non-null   int64
#  10  cc_active30              8448 non-null   int64
#  11  cc_active60              8448 non-null   int64
#  12  cc_active90              8448 non-null   int64
#  13  hotlist_flag             8448 non-null   object
# ...

# %%
sns.countplot(data=df1,x='Occupation_at_source')
# Out:
# <AxesSubplot:xlabel='Occupation_at_source', ylabel='count'>

# %%
sns.boxplot(data=df1,x='Occupation_at_source',y='avg_spends_l3m')
# Out:
# <AxesSubplot:xlabel='Occupation_at_source', ylabel='avg_spends_l3m'>

# %%
df1['cc_limit_laks'] = df1['cc_limit']/100000

# %%
sns.boxplot(data=df1,x='Occupation_at_source',y='cc_limit_laks')
# Out:
# <AxesSubplot:xlabel='Occupation_at_source', ylabel='cc_limit_laks'>

# %%
df1.drop(['userid','card_no','card_bin_no','card_source_date'],axis=1,inplace=True)

# %%
cat=[]
num=[]
for i in df1.columns:
    if df1[i].dtype=="object":
        cat.append(i)
    else:
        num.append(i)
print(cat) 
print(num)
# Out:
# ['Issuer', 'card_type', 'high_networth', 'hotlist_flag', 'other_bank_cc_holding', 'Transactor_revolver', 'Occupation_at_source']
# ['active_30', 'active_60', 'active_90', 'cc_active30', 'cc_active60', 'cc_active90', 'widget_products', 'engagement_products', 'annual_income_at_source', 'bank_vintage', 'T+1_month_activity', 'T+2_month_activity', 'T+3_month_activity', 'T+6_month_activity', 'T+12_month_activity', 'avg_spends_l3m', 'cc_limit', 'cc_limit_laks']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df2[num])
data_standard=scaler.transform(df2[num])
data_standard=pd.DataFrame(data_standard, columns=df2[num].columns)
data_standard.describe()
# Out:
#           active_30     active_60     active_90   cc_active30   cc_active60  \
# count  8.447000e+03  8.447000e+03  8.447000e+03  8.447000e+03  8.447000e+03
# mean  -2.974614e-16 -5.424018e-16  1.063091e-15 -4.587572e-16  1.408710e-16
# std    1.000059e+00  1.000059e+00  1.000059e+00  1.000059e+00  1.000059e+00
# min   -6.428459e-01 -9.897530e-01 -1.339494e+00 -6.298095e-01 -9.693346e-01
# 25%   -6.428459e-01 -9.897530e-01 -1.339494e+00 -6.298095e-01 -9.693346e-01
# 50%   -6.428459e-01 -9.897530e-01  7.465506e-01 -6.298095e-01 -9.693346e-01
# 75%    1.555583e+00  1.010353e+00  7.465506e-01  1.587782e+00  1.031635e+00
# max    1.555583e+00  1.010353e+00  7.465506e-01  1.587782e+00  1.031635e+00
#
#         cc_active90  widget_products  engagement_products  \
# count  8.447000e+03     8.447000e+03         8.447000e+03
# mean   1.595083e-16    -1.129018e-16        -5.420338e-17
# std    1.000059e+00     1.000059e+00         1.000059e+00
# ...

# %%
df2=data_standard

# %%
sns.scatterplot(data=df2,x='annual_income_at_source',y='cc_limit')
# Out:
# <AxesSubplot:xlabel='annual_income_at_source', ylabel='cc_limit'>

# %%
sns.scatterplot(data=df2,x='annual_income_at_source',y='avg_spends_l3m')
# Out:
# <AxesSubplot:xlabel='annual_income_at_source', ylabel='avg_spends_l3m'>

# %%
sns.boxplot(data=df1,x='high_networth',y='annual_income_at_source')
# Out:
# <AxesSubplot:xlabel='high_networth', ylabel='annual_income_at_source'>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),annot=True,fmt=".2f");

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df1,x='card_type',y='avg_spends_l3m')
# Out:
# <AxesSubplot:xlabel='card_type', ylabel='avg_spends_l3m'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df1,x='card_type',hue='active_30')
# Out:
# <AxesSubplot:xlabel='card_type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df1,x='card_type',hue='active_60')
# Out:
# <AxesSubplot:xlabel='card_type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df1,x='card_type',hue='active_90')
# Out:
# <AxesSubplot:xlabel='card_type', ylabel='count'>
