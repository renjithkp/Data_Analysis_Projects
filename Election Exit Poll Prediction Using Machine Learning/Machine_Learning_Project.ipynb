# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Renjith KP\Downloads\Election_Data.csv")

# %% [markdown]
# 1.1 Read the dataset. Do the descriptive statistics and do the null value condition check. Write an inference on it.

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
df.head()
# Out:
#    Unnamed: 0    vote  age  economic.cond.national  economic.cond.household  \
# 0           1  Labour   43                       3                        3
# 1           2  Labour   36                       4                        4
# 2           3  Labour   35                       4                        4
# 3           4  Labour   24                       4                        2
# 4           5  Labour   41                       2                        2
#
#    Blair  Hague  Europe  political.knowledge  gender
# 0      4      1       2                    2  female
# 1      4      4       5                    2    male
# 2      5      2       3                    2    male
# 3      2      1       4                    0  female
# 4      1      1       6                    2    male

# %%
df.shape
# Out:
# (1525, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0                  int64
# vote                       object
# age                         int64
# economic.cond.national      int64
# economic.cond.household     int64
# Blair                       int64
# Hague                       int64
# Europe                      int64
# political.knowledge         int64
# gender                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# vote                       0
# age                        0
# economic.cond.national     0
# economic.cond.household    0
# Blair                      0
# Hague                      0
# Europe                     0
# political.knowledge        0
# gender                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                           count        mean         std   min    25%    50%  \
# Unnamed: 0               1525.0  763.000000  440.373894   1.0  382.0  763.0
# age                      1525.0   54.182295   15.711209  24.0   41.0   53.0
# economic.cond.national   1525.0    3.245902    0.880969   1.0    3.0    3.0
# economic.cond.household  1525.0    3.140328    0.929951   1.0    3.0    3.0
# Blair                    1525.0    3.334426    1.174824   1.0    2.0    4.0
# Hague                    1525.0    2.746885    1.230703   1.0    2.0    2.0
# Europe                   1525.0    6.728525    3.297538   1.0    4.0    6.0
# political.knowledge      1525.0    1.542295    1.083315   0.0    0.0    2.0
#
#                             75%     max
# Unnamed: 0               1144.0  1525.0
# age                        67.0    93.0
# economic.cond.national      4.0     5.0
# economic.cond.household     4.0     5.0
# Blair                       4.0     5.0
# ...

# %%
df[df["political.knowledge"] == 0]
# Out:
#       Unnamed: 0          vote  age  economic.cond.national  \
# 3              4        Labour   24                       4
# 7              8        Labour   77                       3
# 8              9        Labour   39                       3
# 10            11        Labour   39                       3
# 13            14        Labour   66                       3
# ...          ...           ...  ...                     ...
# 1499        1500  Conservative   79                       2
# 1500        1501        Labour   67                       2
# 1510        1511        Labour   73                       4
# 1514        1515        Labour   74                       3
# 1524        1525  Conservative   74                       2
#
#       economic.cond.household  Blair  Hague  Europe  political.knowledge  \
# 3                           2      2      1       4                    0
# 7                           4      4      1       1                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1525 entries, 0 to 1524
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1525 non-null   int64
#  1   vote                     1525 non-null   object
#  2   age                      1525 non-null   int64
#  3   economic.cond.national   1525 non-null   int64
#  4   economic.cond.household  1525 non-null   int64
#  5   Blair                    1525 non-null   int64
#  6   Hague                    1525 non-null   int64
#  7   Europe                   1525 non-null   int64
#  8   political.knowledge      1525 non-null   int64
#  9   gender                   1525 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 119.3+ KB

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.duplicated().sum()
# Out:
# 8

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1517 non-null   object
#  1   age                      1517 non-null   int64
#  2   economic.cond.national   1517 non-null   int64
#  3   economic.cond.household  1517 non-null   int64
#  4   Blair                    1517 non-null   int64
#  5   Hague                    1517 non-null   int64
#  6   Europe                   1517 non-null   int64
#  7   political.knowledge      1517 non-null   int64
#  8   gender                   1517 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 118.5+ KB

# %% [markdown]
# 1.2 Perform Univariate and Bivariate Analysis. Do exploratory data analysis. Check for Outliers.

# %%
sns.boxplot(x=df.age,data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.histplot(x=df.age,data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
fig,axes=plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(15,20)
sns.countplot(data=df,x=df.vote,ax=axes[0][0])
sns.countplot(data=df,x=df["economic.cond.national"],ax=axes[0][1])
sns.countplot(data=df,x=df["economic.cond.household"],ax=axes[1][0])
sns.countplot(data=df,x=df["Blair"],ax=axes[1][1])
sns.countplot(data=df,x=df["Hague"],ax=axes[2][0])
sns.countplot(data=df,x=df["Europe"],ax=axes[2][1])
sns.countplot(data=df,x=df["political.knowledge"],ax=axes[3][0])
sns.countplot(data=df,x=df["gender"],ax=axes[3][1])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df.vote.value_counts()
# Out:
# Labour          1057
# Conservative     460
# Name: vote, dtype: int64

# %%
df["economic.cond.national"].value_counts()
# Out:
# 3    604
# 4    538
# 2    256
# 5     82
# 1     37
# Name: economic.cond.national, dtype: int64

# %%
df["economic.cond.household"].value_counts()
# Out:
# 3    645
# 4    435
# 2    280
# 5     92
# 1     65
# Name: economic.cond.household, dtype: int64

# %%
df["Blair"].value_counts()
# Out:
# 4    833
# 2    434
# 5    152
# 1     97
# 3      1
# Name: Blair, dtype: int64

# %%
df["Hague"].value_counts()
# Out:
# 2    617
# 4    557
# 1    233
# 5     73
# 3     37
# Name: Hague, dtype: int64

# %%
df["Europe"].value_counts()
# Out:
# 11    338
# 6     207
# 3     128
# 4     126
# 5     123
# 9     111
# 8     111
# 1     109
# 10    101
# 7      86
# 2      77
# Name: Europe, dtype: int64

# %%
df["political.knowledge"].value_counts()
# Out:
# 2    776
# 0    454
# 3    249
# 1     38
# Name: political.knowledge, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# female    808
# male      709
# Name: gender, dtype: int64

# %%
sns.countplot(data=df,x=df.gender,hue=df.vote)
plt.title("Gender Vs Party Choice")
# Out:
# Text(0.5, 1.0, 'Gender Vs Party Choice')

# %%
sns.countplot(data=df,x=df.Blair,hue=df.vote)
plt.xlabel("Assessment of the Labour leader")
plt.title("Assessment of the Labour Leader Vs Party Choice")
# Out:
# Text(0.5, 1.0, 'Assessment of the Labour Leader Vs Party Choice')

# %%
sns.countplot(data=df,x=df.Hague,hue=df.vote)
plt.xlabel("Assessment of the Conservative leader")
plt.title("Assessment of the Conservative leader Vs Party Choice")
# Out:
# Text(0.5, 1.0, 'Assessment of the Conservative leader Vs Party Choice')

# %%
sns.countplot(data=df,x=df["economic.cond.national"],hue=df.vote)
plt.xlabel("Assessment of current national economic conditions")
plt.title("Assessment of current national economic conditions Vs Party Choice")
# Out:
# Text(0.5, 1.0, 'Assessment of current national economic conditions Vs Party Choice')

# %%
sns.countplot(data=df,x=df["economic.cond.household"],hue=df.vote)
plt.xlabel("Assessment of current household economic conditions")
plt.title("Assessment of current household economic conditions Vs Party Choice")
# Out:
# Text(0.5, 1.0, 'Assessment of current household economic conditions Vs Party Choice')

# %%
sns.countplot(data=df,x=df["Europe"],hue=df.vote)
plt.xlabel("respondents' attitudes toward European integration")
plt.title("respondents' attitudes toward European integration Vs Party Choice")
# Out:
# Text(0.5, 1.0, "respondents' attitudes toward European integration Vs Party Choice")

# %%
sns.countplot(data=df,x=df["political.knowledge"],hue=df.vote)
plt.xlabel("Knowledge of parties' positions on European integration")
plt.title("Knowledge of parties' positions on European integration Vs Party Choice")
# Out:
# Text(0.5, 1.0, "Knowledge of parties' positions on European integration Vs Party Choice")

# %%
sns.boxplot(data=df,x=df.vote,y=df.age)
# Out:
# <AxesSubplot:xlabel='vote', ylabel='age'>

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt=".2f");

# %%
cont=df.dtypes[(df.dtypes!='ufloat64') & (df.dtypes!='uint64') ].index
plt.figure(figsize=(10,10))
df[cont].boxplot(vert=0)
plt.title('Outliers Check',fontsize=16)
plt.show()

# %% [markdown]
# 1.3 Encode the data (having string values) for Modelling. Is Scaling necessary here or not? Data Split: Split the data into train and test (70:30).

# %%
df.head()
# Out:
#      vote  age  economic.cond.national  economic.cond.household  Blair  Hague  \
# 0  Labour   43                       3                        3      4      1
# 1  Labour   36                       4                        4      4      4
# 2  Labour   35                       4                        4      5      2
# 3  Labour   24                       4                        2      2      1
# 4  Labour   41                       2                        2      1      1
#
#    Europe  political.knowledge  gender
# 0       2                    2  female
# 1       5                    2    male
# 2       3                    2    male
# 3       4                    0  female
# 4       6                    2    male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1517 non-null   object
#  1   age                      1517 non-null   int64
#  2   economic.cond.national   1517 non-null   int64
#  3   economic.cond.household  1517 non-null   int64
#  4   Blair                    1517 non-null   int64
#  5   Hague                    1517 non-null   int64
#  6   Europe                   1517 non-null   int64
#  7   political.knowledge      1517 non-null   int64
#  8   gender                   1517 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 158.5+ KB

# %%
df.vote = df.vote.astype("category")

# %%
df["vote"] = df["vote"].cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1517 non-null   int8
#  1   age                      1517 non-null   int64
#  2   economic.cond.national   1517 non-null   int64
#  3   economic.cond.household  1517 non-null   int64
#  4   Blair                    1517 non-null   int64
#  5   Hague                    1517 non-null   int64
#  6   Europe                   1517 non-null   int64
#  7   political.knowledge      1517 non-null   int64
#  8   gender                   1517 non-null   object
# dtypes: int64(7), int8(1), object(1)
# memory usage: 148.1+ KB

# %%
df_encoded = pd.get_dummies(df,drop_first=True)

# %%
df_encoded
# Out:
#       vote  age  economic.cond.national  economic.cond.household  Blair  \
# 0        1   43                       3                        3      4
# 1        1   36                       4                        4      4
# 2        1   35                       4                        4      5
# 3        1   24                       4                        2      2
# 4        1   41                       2                        2      1
# ...    ...  ...                     ...                      ...    ...
# 1520     0   67                       5                        3      2
# 1521     0   73                       2                        2      4
# 1522     1   37                       3                        3      5
# 1523     0   61                       3                        3      1
# 1524     0   74                       2                        3      2
#
#       Hague  Europe  political.knowledge  gender_male
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1517 non-null   int8
#  1   age                      1517 non-null   int64
#  2   economic.cond.national   1517 non-null   int64
#  3   economic.cond.household  1517 non-null   int64
#  4   Blair                    1517 non-null   int64
#  5   Hague                    1517 non-null   int64
#  6   Europe                   1517 non-null   int64
#  7   political.knowledge      1517 non-null   int64
#  8   gender_male              1517 non-null   uint8
# dtypes: int64(7), int8(1), uint8(1)
# memory usage: 137.8 KB

# %%
df_encoded.vote = df_encoded.vote.astype("category")

df_encoded["economic.cond.national"]=df_encoded["economic.cond.national"].astype("category")

df_encoded["economic.cond.household"]=df_encoded["economic.cond.household"].astype("category")

df_encoded.Blair = df_encoded.Blair.astype("category")

df_encoded.Hague = df_encoded.Hague.astype("category")

df_encoded.Europe  = df_encoded.Europe.astype("category")

df_encoded["political.knowledge"]  = df_encoded["political.knowledge"].astype("category")

# %%
df_encoded.head()
# Out:
#   vote  age economic.cond.national economic.cond.household Blair Hague Europe  \
# 0    1   43                      3                       3     4     1      2
# 1    1   36                      4                       4     4     4      5
# 2    1   35                      4                       4     5     2      3
# 3    1   24                      4                       2     2     1      4
# 4    1   41                      2                       2     1     1      6
#
#   political.knowledge  gender_male
# 0                   2            0
# 1                   2            1
# 2                   2            1
# 3                   0            0
# 4                   2            1

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1524
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vote                     1517 non-null   category
#  1   age                      1517 non-null   int64
#  2   economic.cond.national   1517 non-null   category
#  3   economic.cond.household  1517 non-null   category
#  4   Blair                    1517 non-null   category
#  5   Hague                    1517 non-null   category
#  6   Europe                   1517 non-null   category
#  7   political.knowledge      1517 non-null   category
#  8   gender_male              1517 non-null   uint8
# dtypes: category(7), int64(1), uint8(1)
# memory usage: 77.0 KB

# %% [markdown]
# Labour : 1
# Conservative : 0

# %%
y = df_encoded["vote"]

# %%
df_encoded.drop('vote',axis=1,inplace=True)

# %%
df_encoded.describe().T
# Out:
#               count       mean        std   min   25%   50%   75%   max
# age          1517.0  54.241266  15.701741  24.0  41.0  53.0  67.0  93.0
# gender_male  1517.0   0.467370   0.499099   0.0   0.0   0.0   1.0   1.0

# %%
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler

# %%
scaled = StandardScaler()
df_scaled = scaled.fit_transform(df_encoded)

# %%
df_scaled = pd.DataFrame(df_scaled,columns = df_encoded.columns)

# %%
df_scaled.head()
# Out:
#         age  economic.cond.national  economic.cond.household     Blair  \
# 0 -0.716161               -0.278185                -0.148020  0.565802
# 1 -1.162118                0.856242                 0.926367  0.565802
# 2 -1.225827                0.856242                 0.926367  1.417312
# 3 -1.926617                0.856242                -1.222408 -1.137217
# 4 -0.843577               -1.412613                -1.222408 -1.988727
#
#       Hague    Europe  political.knowledge  gender_male
# 0 -1.419969 -1.437338             0.423832    -0.936736
# 1  1.014951 -0.527684             0.423832     1.067536
# 2 -0.608329 -1.134120             0.423832     1.067536
# 3 -1.419969 -0.830902            -1.421084    -0.936736
# 4 -1.419969 -0.224465             0.423832     1.067536

# %%
df_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      1517 non-null   float64
#  1   economic.cond.national   1517 non-null   float64
#  2   economic.cond.household  1517 non-null   float64
#  3   Blair                    1517 non-null   float64
#  4   Hague                    1517 non-null   float64
#  5   Europe                   1517 non-null   float64
#  6   political.knowledge      1517 non-null   float64
#  7   gender_male              1517 non-null   float64
# dtypes: float64(8)
# memory usage: 94.9 KB

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import roc_auc_score,roc_curve,classification_report,confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(df_encoded, y, test_size=0.30 , random_state=1)

# %%
print('Number of rows and columns of the training set for the independent variables:',X_train.shape)
print('Number of rows and columns of the training set for the dependent variable:',y_train.shape)
print('Number of rows and columns of the test set for the independent variables:',X_test.shape)
print('Number of rows and columns of the test set for the dependent variable:',y_test.shape)
# Out:
# Number of rows and columns of the training set for the independent variables: (1061, 8)
# Number of rows and columns of the training set for the dependent variable: (1061,)
# Number of rows and columns of the test set for the independent variables: (456, 8)
# Number of rows and columns of the test set for the dependent variable: (456,)

# %% [markdown]
# 1.4 Apply Logistic Regression and LDA (linear discriminant analysis).

# %% [markdown]
# Model 1 Logistic Regression Model

# %%
# Fit the Logistic Regression model
model1 = LogisticRegression(solver='newton-cg',random_state=1)
model1.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1, solver='newton-cg')

# %%
ytrain_predict = model1.predict(X_train)
ytest_predict = model1.predict(X_test)

# %%
ytest_predict_prob=model1.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.423638  0.576362
# 1  0.149968  0.850032
# 2  0.007406  0.992594
# 3  0.833214  0.166786
# 4  0.069947  0.930053

# %%
ytrain_predict_prob=model.predict_proba(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,ytrain_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,ytest_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,ytrain_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,ytest_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69       307
#            1       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.79      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75       153
#            1       0.87      0.88      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.84      0.83       456

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,ytrain_predict_prob[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,ytrain_predict_prob[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,ytest_predict_prob[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,ytest_predict_prob[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.890
# AUC for the Test Data: 0.883

# %%
model.coef_
# Out:
# array([[-0.01494785,  0.6287126 ,  0.0630893 ,  0.60086602, -0.82323556,
#         -0.21160763, -0.32201176,  0.19182643]])

# %%
importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance': model1.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)

# %%
print(importances)
# Out:
#                  Attribute  Importance
# 1   economic.cond.national    0.628713
# 3                    Blair    0.600866
# 7              gender_male    0.191826
# 2  economic.cond.household    0.063089
# 0                      age   -0.014948
# 5                   Europe   -0.211608
# 6      political.knowledge   -0.322012
# 4                    Hague   -0.823236

# %%
X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size=0.30 , random_state=1)

# %%
# Fit the Logistic Regression model
model = LogisticRegression(solver='newton-cg',n_jobs=2)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(n_jobs=2, solver='newton-cg')

# %%
ytrain_predict = model.predict(X_train)
ytest_predict = model.predict(X_test)

# %%
ytest_predict_prob=model.predict_proba(X_test)
pd.DataFrame(ytest_predict_prob).head()
# Out:
#           0         1
# 0  0.423790  0.576210
# 1  0.150104  0.849896
# 2  0.007470  0.992530
# 3  0.833130  0.166870
# 4  0.069755  0.930245

# %%
ytrain_predict_prob=model.predict_proba(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,ytrain_predict)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,ytest_predict)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,ytrain_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,ytest_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.64      0.69       307
#            1       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.79      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.73      0.74       153
#            1       0.86      0.88      0.87       303
#
#     accuracy                           0.83       456
#    macro avg       0.81      0.80      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %% [markdown]
# Model 2 : LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
from sklearn import metrics,model_selection

# %%
X_train, X_test, y_train, y_test = train_test_split(df_encoded, y, test_size=0.30 , random_state=1)

# %%
clf = LinearDiscriminantAnalysis()
model2=clf.fit(X_train,y_train)

# %%
#intercept value
clf.intercept_
# Out:
# array([2.62761587])

# %%
#coefficients for the Linear Discriminant Function
clf.coef_
# Out:
# array([[-0.02003705,  0.60492045,  0.05006905,  0.74240039, -0.92663438,
#         -0.22361192, -0.43033484,  0.14907998]])

# %%
X_train.columns
# Out:
# Index(['age', 'economic.cond.national', 'economic.cond.household', 'Blair',
#        'Hague', 'Europe', 'political.knowledge', 'gender_male'],
#       dtype='object')

# %%
a=clf.coef_
np.round(a,2) # rounded up coefficients
# Out:
# array([[-0.02,  0.6 ,  0.05,  0.74, -0.93, -0.22, -0.43,  0.15]])

# %%
# Training Data Class Prediction with a cut-off value of 0.5
pred_class_train = model2.predict(X_train)
# Test Data Class Prediction with a cut-off value of 0.5
pred_class_test = model2.predict(X_test)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,pred_class_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,pred_class_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,pred_class_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,pred_class_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69       307
#            1       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.73      0.74       153
#            1       0.86      0.89      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %%
# Training Data Probability Prediction
pred_prob_train = model2.predict_proba(X_train)

# Test Data Probability Prediction
pred_prob_test = model2.predict_proba(X_test)

# %%
# AUC and ROC for the training data

# calculate AUC
auc = metrics.roc_auc_score(y_train,pred_prob_train[:,1])
print('AUC for the Training Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_train,pred_prob_train[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label = 'Training Data')


# AUC and ROC for the test data

# calculate AUC
auc = metrics.roc_auc_score(y_test,pred_prob_test[:,1])
print('AUC for the Test Data: %.3f' % auc)

#  calculate roc curve
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred_prob_test[:,1])
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr, marker='.',label='Test Data')
# show the plot
plt.legend(loc='best')
plt.show()
# Out:
# AUC for the Training Data: 0.889
# AUC for the Test Data: 0.888

# %%
model2.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
model2.score(X_train,y_train)
# Out:
# 0.8341187558906692

# %%
importances = pd.DataFrame(data={
    'Attribute': X_train.columns,
    'Importance':clf.coef_[0]
})
importances = importances.sort_values(by='Importance', ascending=False)

# %%
print(importances)
# Out:
#                  Attribute  Importance
# 3                    Blair    0.742400
# 1   economic.cond.national    0.604920
# 7              gender_male    0.149080
# 2  economic.cond.household    0.050069
# 0                      age   -0.020037
# 5                   Europe   -0.223612
# 6      political.knowledge   -0.430335
# 4                    Hague   -0.926634

# %% [markdown]
# 1.5	Apply KNN Model and Naïve Bayes Model. Interpret the results.

# %% [markdown]
# MOdel 3 : KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from scipy.stats import zscore

# %%
NNH = KNeighborsClassifier(n_neighbors= 5 , weights = 'distance' )

# %%
# convert the features into z scores as we do not know what units / scales were used and store them in new dataframe
# It is always adviced to scale numeric attributes in models that calculate distances.
df_encoded_z = df_encoded.apply(zscore)
df_encoded_z.describe().T
# Out:
#                           count          mean      std       min       25%  \
# age                      1517.0  1.917458e-17  1.00033 -1.926617 -0.843577
# economic.cond.national   1517.0 -1.984789e-16  1.00033 -2.547041 -0.278185
# economic.cond.household  1517.0 -2.397189e-16  1.00033 -2.296796 -0.148020
# Blair                    1517.0 -1.034842e-16  1.00033 -1.988727 -1.137217
# Hague                    1517.0  5.386448e-17  1.00033 -1.419969 -0.608329
# Europe                   1517.0  6.293947e-17  1.00033 -1.740556 -0.830902
# political.knowledge      1517.0 -7.665442e-16  1.00033 -1.421084 -1.421084
# gender_male              1517.0  2.648581e-16  1.00033 -0.936736 -0.936736
#
#                               50%       75%       max
# age                     -0.079079  0.812836  2.469250
# economic.cond.national  -0.278185  0.856242  1.990670
# economic.cond.household -0.148020  0.926367  2.000755
# Blair                    0.565802  0.565802  1.417312
# ...

# %%
# convert the features into z scores as we do not know what units / scales were used and store them in new dataframe
# It is always adviced to scale numeric attributes in models that calculate distances.
df_scaled_z = df_scaled.apply(zscore)
df_scaled_z.describe().T
# Out:
#                           count          mean      std       min       25%  \
# age                      1517.0  1.917458e-17  1.00033 -1.926617 -0.843577
# economic.cond.national   1517.0 -3.641707e-16  1.00033 -2.547041 -0.278185
# economic.cond.household  1517.0 -2.073709e-16  1.00033 -2.296796 -0.148020
# Blair                    1517.0 -1.642281e-16  1.00033 -1.988727 -1.137217
# Hague                    1517.0  2.927417e-18  1.00033 -1.419969 -0.608329
# Europe                   1517.0  5.357174e-17  1.00033 -1.740556 -0.830902
# political.knowledge      1517.0 -7.617140e-16  1.00033 -1.421084 -1.421084
# gender_male              1517.0  2.648581e-16  1.00033 -0.936736 -0.936736
#
#                               50%       75%       max
# age                     -0.079079  0.812836  2.469250
# economic.cond.national  -0.278185  0.856242  1.990670
# economic.cond.household -0.148020  0.926367  2.000755
# Blair                    0.565802  0.565802  1.417312
# ...

# %%
# store the normalized features data into np array 

X = np.array(df_encoded_z)
X.shape
# Out:
# (1517, 8)

# %%
# store the normalized features data into np array 

X = np.array(df_scaled_z)
X.shape
# Out:
# (1517, 8)

# %%
# Split X and y into training and test set in 70:30 ratio

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1)

# %%
KNN_model=KNeighborsClassifier(n_neighbors=5,weights='distance')

# %%
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=18, weights='distance')

# %%
# For every test data point, predict it's label based on 5 nearest neighbours in this model. The majority class will 
# be assigned to the test data point

predicted_labels_test = KNN_model.predict(X_test)
KNN_model.score(X_test, y_test)
# Out:
# 0.8355263157894737

# %%
predicted_labels_train = KNN_model.predict(X_train)
KNN_model.score(X_train, y_train)
# Out:
# 1.0

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       307
#            1       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.68      0.73       153
#            1       0.85      0.91      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.80      0.81       456
# weighted avg       0.83      0.84      0.83       456

# %%
# empty list that will hold accuracy scores
ac_scores = []

# perform accuracy metrics for values from 1,3,5....19
for k in range(1,20,2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    # evaluate test accuracy
    scores = knn.score(X_test, y_test)
    ac_scores.append(scores)

# changing to misclassification error
MCE = [1 - x for x in ac_scores]
MCE
# Out:
# [0.2171052631578947,
#  0.1885964912280702,
#  0.17543859649122806,
#  0.18201754385964908,
#  0.17763157894736847,
#  0.17105263157894735,
#  0.17763157894736847,
#  0.17324561403508776,
#  0.16666666666666663,
#  0.16666666666666663]

# %%
# plot misclassification error vs k
plt.plot(range(1,20,2), MCE)
plt.xlabel('Number of Neighbors K')
plt.ylabel('Misclassification Error')
plt.show()

# %%
model3=KNeighborsClassifier(n_neighbors=18,weights='uniform')
model3.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=18)

# %%
predicted_labels_test = model3.predict(X_test)

predicted_labels_train = model3.predict(X_train)

# %%
model3.score(X_test, y_test)
# Out:
# 0.8442982456140351

# %%
model3.score(X_train, y_train)
# Out:
# 0.8426013195098964

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72       307
#            1       0.88      0.90      0.89       754
#
#     accuracy                           0.84      1061
#    macro avg       0.81      0.80      0.81      1061
# weighted avg       0.84      0.84      0.84      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75       153
#            1       0.86      0.91      0.89       303
#
#     accuracy                           0.84       456
#    macro avg       0.83      0.81      0.82       456
# weighted avg       0.84      0.84      0.84       456

# %%
KNN_model=KNeighborsClassifier(n_neighbors=17,weights='distance')
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=17, weights='distance')

# %%
## Performance Matrix on train data set
y_train_predict = KNN_model.predict(X_train)
model_score = KNN_model.score(X_train, y_train)
print(model_score)
print(metrics.confusion_matrix(y_train, y_train_predict))
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 1.0
# [[307   0]
#  [  0 754]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       307
#            1       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061

# %%
## Performance Matrix on test data set
y_test_predict = KNN_model.predict(X_test)
model_score = KNN_model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.8267543859649122
# [[100  53]
#  [ 26 277]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.65      0.72       153
#            1       0.84      0.91      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.78      0.80       456
# weighted avg       0.82      0.83      0.82       456

# %%
KNN_model=KNeighborsClassifier(n_neighbors=5,weights='distance')
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
## Performance Matrix on train data set
y_train_predict = KNN_model.predict(X_train)
model_score = KNN_model.score(X_train, y_train)
print(model_score)
print(metrics.confusion_matrix(y_train, y_train_predict))
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 0.9990627928772259
# [[332   0]
#  [  1 734]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       332
#            1       1.00      1.00      1.00       735
#
#     accuracy                           1.00      1067
#    macro avg       1.00      1.00      1.00      1067
# weighted avg       1.00      1.00      1.00      1067

# %%
## Performance Matrix on test data set
y_test_predict = KNN_model.predict(X_test)
model_score = KNN_model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.8144104803493449
# [[ 91  39]
#  [ 46 282]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.70      0.68       130
#            1       0.88      0.86      0.87       328
#
#     accuracy                           0.81       458
#    macro avg       0.77      0.78      0.78       458
# weighted avg       0.82      0.81      0.82       458

# %%
KNN_model=KNeighborsClassifier(n_neighbors=15,weights='distance')
KNN_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15, weights='distance')

# %%
## Performance Matrix on train data set
y_train_predict = KNN_model.predict(X_train)
model_score = KNN_model.score(X_train, y_train)
print(model_score)
print(metrics.confusion_matrix(y_train, y_train_predict))
print(metrics.classification_report(y_train, y_train_predict))
# Out:
# 0.9990627928772259
# [[332   0]
#  [  1 734]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       332
#            1       1.00      1.00      1.00       735
#
#     accuracy                           1.00      1067
#    macro avg       1.00      1.00      1.00      1067
# weighted avg       1.00      1.00      1.00      1067

# %%
## Performance Matrix on test data set
y_test_predict = KNN_model.predict(X_test)
model_score = KNN_model.score(X_test, y_test)
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))
print(metrics.classification_report(y_test, y_test_predict))
# Out:
# 0.8100436681222707
# [[ 86  44]
#  [ 43 285]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66       130
#            1       0.87      0.87      0.87       328
#
#     accuracy                           0.81       458
#    macro avg       0.77      0.77      0.77       458
# weighted avg       0.81      0.81      0.81       458

# %% [markdown]
# Model 4 :Gaussian Naive Bayes

# %%
X_train, X_test, y_train, y_test = train_test_split(df_encoded, y, test_size=0.30 , random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
model4 = GaussianNB()
model4.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_train_predict = model4.predict(X_train)
model_score = model4.score(X_train, y_train)                      ## Accuracy
print(model_score)
print(metrics.confusion_matrix(y_train, y_train_predict))          ## confusion_matrix
print(metrics.classification_report(y_train, y_train_predict))     ## classification_report
# Out:
# 0.8350612629594723
# [[211  96]
#  [ 79 675]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       307
#            1       0.88      0.90      0.89       754
#
#     accuracy                           0.84      1061
#    macro avg       0.80      0.79      0.80      1061
# weighted avg       0.83      0.84      0.83      1061

# %%
## Performance Matrix on test data set
y_test_predict = model4.predict(X_test)
model_score = model4.score(X_test, y_test)                    ## Accuracy
print(model_score)
print(metrics.confusion_matrix(y_test, y_test_predict))         ## confusion_matrix
print(metrics.classification_report(y_test, y_test_predict))    ## classification_report
# Out:
# 0.8223684210526315
# [[112  41]
#  [ 40 263]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       153
#            1       0.87      0.87      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.80      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_train_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_test_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71       307
#            1       0.88      0.90      0.89       754
#
#     accuracy                           0.84      1061
#    macro avg       0.80      0.79      0.80      1061
# weighted avg       0.83      0.84      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73       153
#            1       0.87      0.87      0.87       303
#
#     accuracy                           0.82       456
#    macro avg       0.80      0.80      0.80       456
# weighted avg       0.82      0.82      0.82       456

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,y_train_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,y_test_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
model4.score(X_train, y_train)
# Out:
# 0.8350612629594723

# %%
model4.score(X_test, y_test)
# Out:
# 0.8223684210526315

# %% [markdown]
# 1.6) Model Tuning  , Bagging and Boosting . Apply grid search on each model (include all models) and make models on best_params. Define a logic behind choosing particular values for different hyper-parameters for grid search. Compare and comment on performances of all. Comment on feature importance if applicable. Successful implementation of both algorithms along with inferences and comments on the model performances.

# %% [markdown]
# MOdel 5 : Bagging

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
dTree = DecisionTreeClassifier(criterion = 'gini', random_state=1)
dTree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
print(dTree.score(X_train, y_train))
print(dTree.score(X_test, y_test))
# Out:
# 1.0
# 0.7960526315789473

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfcl = RandomForestClassifier(n_estimators = 50, random_state=1,max_features=4)
rfcl = rfcl.fit(X_train, y_train)

# %%
y_predict = rfcl.predict(X_test)
print(rfcl.score(X_test, y_test))
cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8092105263157895
# <AxesSubplot:>

# %%
y_predict_train = rfcl.predict(X_train)
print(rfcl.score(X_train, y_train))
cm=metrics.confusion_matrix(y_train, y_train,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 1.0
# <AxesSubplot:>

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_predict_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       307
#            1       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       153
#            1       0.85      0.86      0.86       303
#
#     accuracy                           0.81       456
#    macro avg       0.79      0.78      0.78       456
# weighted avg       0.81      0.81      0.81       456

# %% [markdown]
# Model 5 : Bagging

# %%
X_train, X_test, y_train, y_test = train_test_split(df_encoded, y, test_size=0.30 , random_state=1)

# %%
cart_random = RandomForestClassifier()

Bagging_model_random=BaggingClassifier(base_estimator=cart_random,n_estimators=50,random_state=1)
Bagging_model_random.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=50,
#                   random_state=1)

# %%
y_train_predict = Bagging_model_random.predict(X_train)
y_test_predict = Bagging_model_random.predict(X_test)
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_train_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_test_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94       307
#            1       0.96      0.99      0.98       754
#
#     accuracy                           0.96      1061
#    macro avg       0.97      0.94      0.96      1061
# weighted avg       0.96      0.96      0.96      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.79      0.67      0.73       153
#            1       0.85      0.91      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.79      0.80       456
# weighted avg       0.83      0.83      0.83       456

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,y_train_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,y_test_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %% [markdown]
# Model 6 : Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
abcl = AdaBoostClassifier(n_estimators=10, random_state=1)
#abcl = AdaBoostClassifier( n_estimators=50,random_state=1)
abcl = abcl.fit(X_train, y_train)

# %%
y_predict = abcl.predict(X_test)
print(abcl.score(X_test , y_test))

cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8201754385964912
# <AxesSubplot:>

# %%
y_predict_train = abcl.predict(X_train)
print(abcl.score(X_train , y_train))

cm=metrics.confusion_matrix(y_train, y_predict_train,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8426013195098964
# <AxesSubplot:>

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_predict_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       307
#            1       0.91      0.94      0.93       754
#
#     accuracy                           0.89      1061
#    macro avg       0.88      0.86      0.87      1061
# weighted avg       0.89      0.89      0.89      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74       153
#            1       0.85      0.91      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.80      0.81       456
# weighted avg       0.83      0.84      0.83       456

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,y_predict_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,y_predict)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(random_state=1)
gbcl = gbcl.fit(X_train, y_train)

# %%
y_predict = gbcl.predict(X_test)
print(gbcl.score(X_test, y_test))
cm=metrics.confusion_matrix(y_test, y_predict,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8355263157894737
# <AxesSubplot:>

# %%
y_predict_train = gbcl.predict(X_train)
print(abcl.score(X_train , y_train))

cm=metrics.confusion_matrix(y_train, y_predict_train,labels=[0, 1])

df_cm = pd.DataFrame(cm, index = [i for i in ["No","Yes"]],
                  columns = [i for i in ["No","Yes"]])
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True ,fmt='g')
# Out:
# 0.8426013195098964
# <AxesSubplot:>

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_predict_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       307
#            1       0.91      0.94      0.93       754
#
#     accuracy                           0.89      1061
#    macro avg       0.88      0.86      0.87      1061
# weighted avg       0.89      0.89      0.89      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74       153
#            1       0.85      0.91      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.80      0.81       456
# weighted avg       0.83      0.84      0.83       456

# %% [markdown]
# Model 7 : Logistic Regression MOdel Tuning

# %%
parameters = {
    "C": [0.001, 0.01, 0.1, 1.],
    "penalty": ["l1", "l2"]
}

# %%
# Fit the Logistic Regression model
model = LogisticRegression(solver='newton-cg',n_jobs=2)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(n_jobs=2, solver='newton-cg')

# %%
grid_search = GridSearchCV(estimator=model, param_grid=parameters, n_jobs=2, cv=5, scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 20 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
predicted_labels_test = grid_search.predict(X_test)

predicted_labels_train = grid_search.predict(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.63      0.68       307
#            1       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.78      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       153
#            1       0.86      0.88      0.87       303
#
#     accuracy                           0.83       456
#    macro avg       0.81      0.80      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %% [markdown]
# Model 8 : Grid search toning on LDA

# %%
grid = dict()
grid['solver'] = ['svd', 'lsqr', 'eigen']

# %%
search = GridSearchCV(model2, grid, scoring='accuracy', cv=5, n_jobs=2)

# %%
search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearDiscriminantAnalysis(), n_jobs=2,
#              param_grid={'solver': ['svd', 'lsqr', 'eigen']},
#              scoring='accuracy')

# %%
predicted_labels_test = search.predict(X_test)

predicted_labels_train = search.predict(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69       307
#            1       0.86      0.91      0.89       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.78      0.79      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.77      0.73      0.74       153
#            1       0.86      0.89      0.88       303
#
#     accuracy                           0.83       456
#    macro avg       0.82      0.81      0.81       456
# weighted avg       0.83      0.83      0.83       456

# %% [markdown]
# Model 9 : Toning KNN Model

# %% [markdown]
# param_grid = {'n_neighbors': list(range(1,9)),
#              'algorithm': ('auto', 'ball_tree', 'kd_tree' , 'brute') }

# %%
from sklearn.model_selection import GridSearchCV
gs = GridSearchCV(KNN_model,param_grid,cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=KNeighborsClassifier(n_neighbors=17, weights='distance'),
#              param_grid={'algorithm': ('auto', 'ball_tree', 'kd_tree', 'brute'),
#                          'n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8]})

# %%
gs.best_params_
# Out:
# {'algorithm': 'brute', 'n_neighbors': 8}

# %%
gs.cv_results_['params']
# Out:
# [{'algorithm': 'auto', 'n_neighbors': 1},
#  {'algorithm': 'auto', 'n_neighbors': 2},
#  {'algorithm': 'auto', 'n_neighbors': 3},
#  {'algorithm': 'auto', 'n_neighbors': 4},
#  {'algorithm': 'auto', 'n_neighbors': 5},
#  {'algorithm': 'auto', 'n_neighbors': 6},
#  {'algorithm': 'auto', 'n_neighbors': 7},
#  {'algorithm': 'auto', 'n_neighbors': 8},
#  {'algorithm': 'ball_tree', 'n_neighbors': 1},
#  {'algorithm': 'ball_tree', 'n_neighbors': 2},
#  {'algorithm': 'ball_tree', 'n_neighbors': 3},
#  {'algorithm': 'ball_tree', 'n_neighbors': 4},
#  {'algorithm': 'ball_tree', 'n_neighbors': 5},
#  {'algorithm': 'ball_tree', 'n_neighbors': 6},
#  {'algorithm': 'ball_tree', 'n_neighbors': 7},
#  {'algorithm': 'ball_tree', 'n_neighbors': 8},
#  {'algorithm': 'kd_tree', 'n_neighbors': 1},
#  {'algorithm': 'kd_tree', 'n_neighbors': 2},
#  {'algorithm': 'kd_tree', 'n_neighbors': 3},
#  {'algorithm': 'kd_tree', 'n_neighbors': 4},
#  {'algorithm': 'kd_tree', 'n_neighbors': 5},
# ...

# %%
gs.cv_results_['mean_test_score']
# Out:
# array([0.73233236, 0.7323235 , 0.77663212, 0.77757995, 0.79170431,
#        0.79078306, 0.79359996, 0.79644787, 0.73421915, 0.73044557,
#        0.77663212, 0.77663212, 0.78794402, 0.79361325, 0.78983524,
#        0.79550447, 0.73233236, 0.7323235 , 0.77663212, 0.77757995,
#        0.79170431, 0.79078306, 0.79359996, 0.79644787, 0.73422801,
#        0.7332669 , 0.78511826, 0.77757552, 0.79170431, 0.79643901,
#        0.79549119, 0.7983258 ])

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=KNeighborsClassifier(n_neighbors=17, weights='distance'),
#              param_grid={'algorithm': ('auto', 'ball_tree', 'kd_tree', 'brute'),
#                          'n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8]})

# %%
predicted_labels_test = gs.predict(X_test)

predicted_labels_train = gs.predict(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       307
#            1       1.00      1.00      1.00       754
#
#     accuracy                           1.00      1061
#    macro avg       1.00      1.00      1.00      1061
# weighted avg       1.00      1.00      1.00      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.64      0.69       153
#            1       0.83      0.89      0.86       303
#
#     accuracy                           0.81       456
#    macro avg       0.79      0.77      0.78       456
# weighted avg       0.81      0.81      0.80       456

# %% [markdown]
# Model 10 : Grid Search Toning Bagging

# %%
n_estimators = [10, 100, 1000]

# %%
grid = dict(n_estimators=n_estimators)

# %%
grid_search = GridSearchCV(estimator=Bagging_model_random, param_grid=grid)

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
# ...

# %% [markdown]
# Model 10 : Grid Search Toning Boosting

# %%
n_estimators = [10, 100, 1000]
learning_rate = [0.001, 0.01, 0.1]
subsample = [0.5, 0.7, 1.0]
max_depth = [3, 7, 9]

# %%
grid = dict(learning_rate=learning_rate, n_estimators=n_estimators, subsample=subsample, max_depth=max_depth)

# %%
grid_search = GridSearchCV(estimator=gbcl, param_grid=grid, n_jobs=2, cv=5, scoring='accuracy',error_score=0)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=0,
#              estimator=GradientBoostingClassifier(random_state=1), n_jobs=2,
#              param_grid={'n_estimators': [10, 100, 1000]}, scoring='accuracy')

# %%
predicted_labels_test = grid_search.predict(X_test)

predicted_labels_train = grid_search.predict(X_train)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,predicted_labels_train)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,predicted_labels_test)),annot=True,fmt='.5g',cmap='Blues',ax=a[0][1]);
a[0][1].set_title('Test Data');

# %%
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,predicted_labels_train),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,predicted_labels_test),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81       307
#            1       0.91      0.94      0.93       754
#
#     accuracy                           0.89      1061
#    macro avg       0.88      0.86      0.87      1061
# weighted avg       0.89      0.89      0.89      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.80      0.69      0.74       153
#            1       0.85      0.91      0.88       303
#
#     accuracy                           0.84       456
#    macro avg       0.82      0.80      0.81       456
# weighted avg       0.83      0.84      0.83       456

# %% [markdown]
# SMOTE

# %%
#from numpy import where
#import matplotlib.pyplot as plt

#from collections import Counter
#from sklearn.datasets import make_classification
#from imblearn.over_sampling import SMOTE

# %%
#counter=Counter(y)
#counter
# Out:
# Counter({1: 1057, 0: 460})

# %%
#X=df_encoded

# %%
#oversample = SMOTE()
#X, y = oversample.fit_resample(X, y)

# %%
counter=Counter(y)
counter
# Out:
# Counter({1: 1057, 0: 1057})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
cart_random = RandomForestClassifier()

Bagging_model_random=BaggingClassifier(base_estimator=cart_random,n_estimators=100,random_state=1)
Bagging_model_random.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=RandomForestClassifier(), n_estimators=100,
#                   random_state=1)

# %%
cart = DecisionTreeClassifier()

Bagging_model=BaggingClassifier(base_estimator=cart,n_estimators=100,random_state=1)
Bagging_model.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\ensemble\_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100,
#                   random_state=1)

# %%
y_train_predict = Bagging_model.predict(X_train)
y_test_predict = Bagging_model.predict(X_test)
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_train_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_test_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       729
#            1       1.00      1.00      1.00       750
#
#     accuracy                           1.00      1479
#    macro avg       1.00      1.00      1.00      1479
# weighted avg       1.00      1.00      1.00      1479
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86       328
#            1       0.87      0.82      0.84       307
#
#     accuracy                           0.85       635
#    macro avg       0.86      0.85      0.85       635
# weighted avg       0.85      0.85      0.85       635

# %%
y_train_predict = Bagging_model_random.predict(X_train)
y_test_predict = Bagging_model_random.predict(X_test)
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,y_train_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,y_test_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       729
#            1       0.98      0.96      0.97       750
#
#     accuracy                           0.97      1479
#    macro avg       0.97      0.97      0.97      1479
# weighted avg       0.97      0.97      0.97      1479
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88       328
#            1       0.88      0.85      0.86       307
#
#     accuracy                           0.87       635
#    macro avg       0.87      0.87      0.87       635
# weighted avg       0.87      0.87      0.87       635

# %%
model_score = Bagging_model.score(X_test, y_test)
print(model_score)
# Out:
# 0.8535433070866142

# %%
model_score = Bagging_model_random.score(X_test, y_test)
print(model_score)
# Out:
# 0.8708661417322835

# %%
model_score = Bagging_model.score(X_train, y_train)
print(model_score)
# Out:
# 0.9986477349560514

# %%
model_score = Bagging_model_random.score(X_train, y_train)
print(model_score)
# Out:
# 0.9716024340770791

# %%
    from sklearn import linear_model, decomposition, datasets
    from sklearn.pipeline import Pipeline
    from sklearn.model_selection import GridSearchCV
    from sklearn.preprocessing import StandardScaler

# %%
logistic_Reg=LogisticRegression()

# %%
grid={"C":np.logspace(-3,3,7), "penalty":["l1","l2"]}

# %%
gs = GridSearchCV(model,grid,cv=10)

# %%
gs.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print("tuned hpyerparameters :(best parameters) ",gs.best_params_)
print("accuracy :",gs.best_score_)
# Out:
# tuned hpyerparameters :(best parameters)  {'C': 1.0, 'penalty': 'l2'}
# accuracy : 0.8312995944277907

# %%
# Fit the Logistic Regression model
model = LogisticRegression(C=0.1,penalty='l2',random_state=1)
model.fit(X_train, y_train)
# Out:
# C:\Users\Renjith KP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.1, random_state=1)

# %%
ytrain_predict = model.predict(X_train)
ytest_predict = model.predict(X_test)

# %%
f,a =  plt.subplots(1,2,sharex=True,sharey=True,squeeze=False)

#Plotting confusion matrix for the different models for the Training Data

plot_0 = sns.heatmap((metrics.confusion_matrix(y_train,ytrain_predict)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][0]);
a[0][0].set_title('Training Data')

plot_1 = sns.heatmap((metrics.confusion_matrix(y_test,ytest_predict)),annot=True,fmt='.5g',cmap='Greys',ax=a[0][1]);
a[0][1].set_title('Test Data');
print('Classification Report of the training data:\n\n',metrics.classification_report(y_train,ytrain_predict),'\n')
print('Classification Report of the test data:\n\n',metrics.classification_report(y_test,ytest_predict),'\n')
# Out:
# Classification Report of the training data:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.63      0.68       307
#            1       0.86      0.91      0.88       754
#
#     accuracy                           0.83      1061
#    macro avg       0.80      0.77      0.78      1061
# weighted avg       0.83      0.83      0.83      1061
#
#
# Classification Report of the test data:
#
#                precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74       153
#            1       0.86      0.88      0.87       303
#
#     accuracy                           0.83       456
#    macro avg       0.81      0.80      0.81       456
# weighted avg       0.83      0.83      0.83       456
